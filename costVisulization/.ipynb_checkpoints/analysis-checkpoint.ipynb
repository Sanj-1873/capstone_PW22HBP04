# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#Getting Global Data 

region=["us-east-1", "us-east-2", "us-west-1", "us-west-2", "ap-south-1", "ap-northeast-3", "ap-northeast-2", "ap-southeast-1", "ap-southeast-2", "ap-northeast-1", "ca-central-1", "eu-central-1", "eu-west-1", "eu-west-2", "eu-west-3", "eu-north-1", "sa-east-1"]
data_globally = pd.DataFrame()
for region_name in region:
    df = pd.read_csv("data/region-"+ region_name +".csv")
    data_globally = pd.concat([df, data_globally])
data_globally

data_globally = data_globally.rename(columns = {'instance': 'instanceid'}, inplace = False)
data_globally
# Out:
#     id account_id     region           instanceid                    subnet  \
# 0    1          3  us-west-2  i-0dbfc1626032bfe20           subnet-0cd21d68
# 1    2          3  us-west-2  i-0cba1f28c31503b50           subnet-0cd21d68
# 2    3          3  us-west-2  i-0b216612d60835f3c           subnet-6437d712
# 3    4          3  us-west-2  i-0ff88a8f42661647d           subnet-6437d712
# 4    5          3  us-west-2  i-0379d1cb39344d710           subnet-6437d712
# 5    6          3  us-west-2  i-06cc58930e36202c2  subnet-0b5148f4f6865e494
# 6    7          3  us-west-2  i-01508e94d4f9b43e0  subnet-0b5148f4f6865e494
# 7    8          3  us-west-2  i-0b84d4fe7aaf67ff8  subnet-0a7c61918f073f353
# 0    1          3  us-east-2  i-02975fe154c1d09be           subnet-6426ef0d
# 1    2          3  us-east-2  i-0317bb7b8eba49555           subnet-6426ef0d
# 2    3          3  us-east-2  i-008a18849dba03a44           subnet-6426ef0d
# 3    4          3  us-east-2  i-095f8606a333151c9           subnet-6426ef0d
# 4    5          3  us-east-2  i-03fef90366aaaf623           subnet-6426ef0d
# 5    6          3  us-east-2  i-0c0320f2e714c4c95           subnet-98fce7e0
# 0    1          3  us-east-1  i-09fe0fc041d31a6bf           subnet-16df623c
# 1    2          3  us-east-1  i-0467b6c8deca56670           subnet-16df623c
# 2    3          3  us-east-1  i-08fbda02cc4e4794b           subnet-16df623c
# 3    4          3  us-east-1  i-04af786811b0a4cb6           subnet-16df623c
# 4    5          3  us-east-1  i-035f58d5d120cc030           subnet-16df623c
# 5    6          3  us-east-1  i-07f1ec1e99582666b           subnet-16df623c
# 6    7          3  us-east-1  i-0b2bb9dd2b8f28ffe           subnet-73922059
# 7    8          3  us-east-1  i-082b6c9bbe0c45c56           subnet-947a17e2
# 8    9          3  us-east-1  i-0fe188797424d88a2           subnet-16df623c
# 9   10          3  us-east-1  i-0e46a840661f9967e           subnet-16df623c
# 10  11          3  us-east-1  i-0a9731eebf19b1853           subnet-16df623c
#
#    instancetype                 launchtime statecode statename  \
# 0     t2.medium  2019-06-10T06:12:36+00:00        16   running
# 1      t2.micro  2019-10-11T10:59:10+00:00        80   stopped
# 2      t2.micro  2019-10-04T06:11:26+00:00        80   stopped
# 3      t2.micro  2019-10-11T11:05:04+00:00        80   stopped
# 4      t2.micro  2021-01-21T03:22:33+00:00        16   running
# 5       t2.nano  2021-08-05T05:59:30+00:00        16   running
# 6       t2.nano  2021-08-05T06:01:27+00:00        16   running
# 7       t2.nano  2021-08-05T05:57:34+00:00        16   running
# 0      t2.large  2021-06-03T04:25:32+00:00        16   running
# 1      t2.large  2017-09-27T03:59:58+00:00        80   stopped
# 2     t2.medium  2018-12-14T09:27:06+00:00        16   running
# 3      t2.micro  2021-03-09T12:56:51+00:00        16   running
# 4     t2.xlarge  2021-07-21T16:58:02+00:00        16   running
# 5     t2.medium  2021-10-01T07:52:28+00:00        16   running
# 0     m4.xlarge  2021-02-23T11:58:54+00:00        16   running
# 1    m4.4xlarge  2021-06-06T04:25:58+00:00        16   running
# 2      t2.large  2020-06-25T06:41:04+00:00        80   stopped
# 3     t2.medium  2021-06-21T03:23:20+00:00        80   stopped
# 4     t2.medium  2020-02-04T05:36:01+00:00        80   stopped
# 5     t2.medium  2020-05-22T12:55:51+00:00        80   stopped
# 6     t2.medium  2020-07-02T15:57:11+00:00        16   running
# 7     t2.medium  2021-06-15T10:02:37+00:00        16   running
# 8      t2.small  2021-07-20T10:24:18+00:00        16   running
# 9     t2.medium  2021-10-01T10:28:30+00:00        80   stopped
# 10    t2.medium  2021-10-01T10:35:47+00:00        16   running
#
#                                                  name
# 0                                            RASA New
# 1                                           services2
# 2                                 windows -services 3
# 3                                           services1
# 4                                          zabbix-5.2
# 5   EC2ContainerService-eox-eks-EcsInstanceAsg-916...
# 6   EC2ContainerService-eox-eks-EcsInstanceAsg-916...
# 7          ECS Instance - EC2ContainerService-eox-eks
# 0                                                Demo
# 1                                          track2save
# 2                                             Marquis
# 3                                              harsha
# 4                                            staging2
# 5                                            keycloak
# 0                                    Bizchoice.oxzion
# 1                                            Anaconda
# 2                                        moverschoice
# 3                                           EOS - PRO
# 4                                           liveziLLA
# 5                                               helpy
# 6                                       arrowhead-iis
# 7                                             skynew1
# 8                                             website
# 9                                          moverstest
# 10                                     movers-restore

# %%
# global data grpahs  --> Where are the instances located?? 

y = data_globally.groupby('region').count()
ec2_distribution = y["id"]
if ec2_distribution.empty:
    pass
else:
    ec2_distribution.plot.bar()

# %%
regions = data_globally['region'].unique()
df_names = []
for region in regions:
    region = region.replace("-","_")
    df_names.append('ec2_stats_'+region)
print(df_names)
# Out:
# ['ec2_stats_us_west_2', 'ec2_stats_us_east_2', 'ec2_stats_us_east_1']

# %%
#Merging data together
for region in regions:
    cpu = pd.read_csv("data/region-"+region +"-cpuutilization.csv")
    #print(cpu.head())
    network_in = pd.read_csv("data/region-"+region+"-networkin.csv")
    #print(network_in.head())
    network_out = pd.read_csv("data/region-"+region+"-networkout.csv")
    #print(network_out.head())
    network = network_in.join(network_out.set_index('instanceid'),on='instanceid',how='outer')
    ec2_stats = network.join(cpu.set_index('instanceid'),on='instanceid',how='outer')
    ec2_stats = ec2_stats.join(data_globally.set_index('instanceid'),on='instanceid',how='inner')
    
    name = region.replace("-","_")
    def determine_state(ec2_stats, cid):
        state = []
        for i in range(len(cid)):
            if((ec2_stats[" cpuutilization%"][i] < 1) and (ec2_stats[" networkoutGiB"][i] < 1) and (ec2_stats[" networkinGiB"][i] < 1)):
        #print(ec2_stats["networkinGiB"])
                state.append('idle')
            else:
                state.append('active')
        return state

    determine_state(ec2_stats, ec2_stats["instanceid"])
    ec2_stats = ec2_stats.assign(state = determine_state(ec2_stats, ec2_stats["instanceid"]) )
    
    
    ec2_stats.to_csv("ec2_stats_"+name+".csv")
    #print(ec2_stats["cpuutilization%"])

# %%
    
ec2_stats = pd.read_csv("ec2_stats_us_east_1.csv")
ec2_stats.head()
# Out:
#    Unnamed: 0           instanceid   networkinGiB   networkoutGiB  \
# 0           0  i-09fe0fc041d31a6bf       1.283368        9.585009
# 1           1  i-0467b6c8deca56670       0.421518        6.257515
# 2           2  i-08fbda02cc4e4794b       0.000000        0.000000
# 3           3  i-04af786811b0a4cb6       0.000000        0.000000
# 4           4  i-035f58d5d120cc030       0.000000        0.000000
#
#     cpuutilization%  id  account_id     region           subnet instancetype  \
# 0          2.007669   1           3  us-east-1  subnet-16df623c    m4.xlarge
# 1          4.421625   2           3  us-east-1  subnet-16df623c   m4.4xlarge
# 2          0.000000   3           3  us-east-1  subnet-16df623c     t2.large
# 3          0.000000   4           3  us-east-1  subnet-16df623c    t2.medium
# 4          0.000000   5           3  us-east-1  subnet-16df623c    t2.medium
#
#                   launchtime  statecode statename              name   state
# 0  2021-02-23T11:58:54+00:00         16   running  Bizchoice.oxzion  active
# 1  2021-06-06T04:25:58+00:00         16   running          Anaconda  active
# 2  2020-06-25T06:41:04+00:00         80   stopped      moverschoice    idle
# 3  2021-06-21T03:23:20+00:00         80   stopped         EOS - PRO    idle
# 4  2020-02-04T05:36:01+00:00         80   stopped         liveziLLA    idle

# %%
# def determine_state(ec2_stats, cid):
#     state = []
#     for i in range(len(cid)):
#         if((ec2_stats[" cpuutilization%"][i] < 1) and (ec2_stats[" networkoutGiB"][i] < 1) and (ec2_stats[" networkinGiB"][i] < 1)):
#     #print(ec2_stats["networkinGiB"])
#             state.append('idle')
#         else:
#             state.append('active')
#     return state
      
# determine_state(ec2_stats, ec2_stats["instanceid"])

# %%
# ec2_stats = ec2_stats.assign(state = determine_state(ec2_stats, ec2_stats["instanceid"]) )
# print(ec2_stats)

# %%
# print(ec2_stats.head())
# print(data_globally.head())
#result= pd.concat([ec2_stats,data_globally])
# result = ec2_stats.join(data_globally.set_index('instanceid'),on='instanceid',how='inner')
# result   
# data_globally
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6992/2389265803.py in <module>
#       2 # print(data_globally.head())
#       3 #result= pd.concat([ec2_stats,data_globally])
# ----> 4 result = ec2_stats.join(data_globally.set_index('instanceid'),on='instanceid',how='inner')
#       5 result
#       6 data_globally
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9093         5  K5  A5  NaN
#    9094         """
# -> 9095         return self._join_compat(
#    9096             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9097         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9124                     sort=sort,
#    9125                 )
# -> 9126             return merge(
#    9127                 self,
#    9128                 other,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
# --> 718         llabels, rlabels = _items_overlap_with_suffix(
#     719             self.left._info_axis, self.right._info_axis, self.suffixes
#     720         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2302
#    2303     if not lsuffix and not rsuffix:
# -> 2304         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2305
#    2306     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['id', 'account_id', 'region', 'subnet', 'instancetype', 'launchtime',
#        'statecode', 'statename', 'name'],
#       dtype='object')

# %%
# state = data_globally.groupby('statename').count()
# print(state)
